# %%
# print()
print("Hello World")
print('Hello World1')
print('''Hello World2''')
"Hello World3"
print("Hello","World","4",sep = ",") # virgülle ayrılmış ifadeleri ekrana yazdırırken aralarına sep = (x) => x değişkenini koyar (eğer sep parametresi koyulmazsa boşluk koyar)
print("Ankara","İstanbul","İzmir","Bursa", sep="-")
print("Eğitime Hoş Geldin", end="!") 
print('Python\'a Giriş Eğitimi') # \ => kaçış parametresi(tırnaktan önce gelir)
# 1. Yorum Satırı

'''
Çoklu Yorum Satırı
'''

# Değişkenler
print("python")
print("python")
print("python")
# printlerin içindeki ifadeyi değitirmek istersek değişkenleri kullanmak daha yararlı olur
a = "python"
print(a)
print(a)
print(a)

# Değişken İsimlendirme
pythonEgitimi = "YetGen" # türkçe karakter ve boşluk içermemeli - başta rakam olmamalı(sonrasında kullanılabilir) - ikinci kelimenin ilk harfi genelde büyük yazılır(birIki gibi)

# type()
a = 2
b = 1.3
c = "python"
d = True
print(type(a)) # int
print(type(b)) # float
print(type(c)) # string(str)
print(type(d)) # boolean(bool)

# Veri Türleri
# int => tam sayı | float => ondalıklı sayı | str => yazı | bool => True ya da False
print(type(12.0))
print(type(-3))
print(type("str"))
print(type(False))

# Matematiksel İşlemler
'''
+ => Toplama
- => Çıkarma
* => Çarpma
/ => Bölme
// => Tam Bölme(5//2=2)
% => Kalan(5%2=1)
** => Üssü
'''
print(8+4)
print(12-3)
print(2*3)
print(6/2)
# print(3/0) => ZeroDivisionError
print(5//2)
print(5%2)
print(2**5)

# string
str1 = "metin1"
str2 = 'metin2'
str3 = '''metin3'''
print(str1[0]) # => m (indexler 0'dan başlar)
print(str2[-1]) # son indexteki eleman
print(str1 + str2) # => metin1metin2
print(f"{str1} = metin1") 

# input()
sayi1 = int(input("Bir Sayı Giriniz\n>>>"))
